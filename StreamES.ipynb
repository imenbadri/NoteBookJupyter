# %%
#grep "Thu Oct 04 11:12:59 +0000" TwitterF.json 
#sed -i ""  "/Oct 04 11:12:59/d" TwitterF.json

import tweepy
import sys
import json
from tweepy import OAuthHandler
from datetime import datetime
from textwrap import TextWrapper
from elasticsearch import Elasticsearch

access_token = "63841766-M25vQQTU87N6IsSXdwcjMJLxTTwRHip2uiIHnAGro"
access_token_secret =  "HROaYaqkPDyGCl1qGjxgLWCEdV1ylnxPxDGFLYtTW7Kyo"

consumer_key =  "Nw7CophXNVDz2XJAM3bv1Q"
consumer_secret =  "mfSqE170bU2JAvFkODH0Hcra3GQ93YohYX5PvMtfNU"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth,wait_on_rate_limit=True ,wait_on_rate_limit_notify=True )


es = Elasticsearch([{'host': 'localhost', 'port': 9200}])

# %%
class StreamApi(tweepy.StreamListener):
    status_wrapper = TextWrapper(width=60, initial_indent= ' ',subsequent_indent='  ')
    
    def on_status(self,status):
        json_data = status._json
        es.index(index="test",doc_type="tt",body=json_data,ignore=400)

# %%
class StreamApi(tweepy.StreamListener):
    status_wrapper = TextWrapper(width=60, initial_indent= ' ',subsequent_indent='  ')
    
    def on_status(self,status):
        json_data = status._json
        es.index(index="demo",doc_type="dem",body=json_data,ignore=400)
class StreamApi(tweepy.StreamListener):
    status_wrapper = TextWrapper(width=60, initial_indent= ' ',subsequent_indent='  ')
    
    def on_status(self,status):
        json_data = status._json
        es.index(index="demo",doc_type="dem",body=json_data,ignore=400)
        
    
        
while True:
        try:
            streamer=tweepy.Stream(auth=auth, listener =StreamApi(),timeout=30)
            terms=["freelance","freelancer","Self employed","auto-entrepreneur"]
            streamer.filter(None,terms)
            #twitterStream.filter(locations=[10.01,46.85,13.09,49.43]) 
        except Exception as e:
                
                print('e')
                pass
# Out:
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# e
# ...

# %%
class StreamApi(tweepy.StreamListener):
    status_wrapper = TextWrapper(width=60, initial_indent= ' ',subsequent_indent='  ')
    
    def on_status(self,status):
        json_data = status._json
        es.index(index="test",doc_type="tt",body=json_data,ignore=400)
        
    
        
while True:
        try:
            streamer=tweepy.Stream(auth=auth, listener =StreamApi(),timeout=30)
            terms=["corona", "coronavirus","covide-19","freelance","freelancer","Self employed","covid-19"]
            streamer.filter(None,terms)
            #twitterStream.filter(locations=[10.01,46.85,13.09,49.43]) 
        except Exception as e:
                
                print('e')
                pass
